# %% [markdown]
# ##Juan Camilo Serrano Correa

# %%
#Importar libreria pandas
import pandas as pd

# %%
#Importar archivo csv, separador '|'
df = pd.read_csv('/content/finalX.csv', sep='|')
#Hechar un vistaso a los primeros registros
df.head()
# Out:
#                  Título   Precio  Rating           Disponibilidad  \
# 0                Título   Precio  Rating           Disponibilidad
# 1  A Light in the Attic  Â£51.77   Three  In stock (22 available)
# 2    Tipping the Velvet  Â£53.74     One  In stock (20 available)
# 3            Soumission  Â£50.10     One  In stock (20 available)
# 4         Sharp Objects  Â£47.82    Four  In stock (20 available)
#
#                 UPC                                        Descripcion
# 0               UPC                                        Descripcion
# 1  a897fe39b1053632  \n    It's hard to imagine a world without A L...
# 2  90fa61229261140a  \n    "Erotic and absorbing...Written with sta...
# 3  6957f44c3847a760  \n    Dans une France assez proche de la nÃ´tr...
# 4  e00eb4fd7b871a48  \n    WICKED above her hipbone, GIRL across he...

# %%
#Eliminar primer registro, ya que se esta repiditendo el nombre de las columnas
df = df.drop(index=0, axis=0)
df.head()
# Out:
#                                   Título   Precio Rating  \
# 1                   A Light in the Attic  Â£51.77  Three
# 2                     Tipping the Velvet  Â£53.74    One
# 3                             Soumission  Â£50.10    One
# 4                          Sharp Objects  Â£47.82   Four
# 5  Sapiens: A Brief History of Humankind  Â£54.23   Five
#
#             Disponibilidad               UPC  \
# 1  In stock (22 available)  a897fe39b1053632
# 2  In stock (20 available)  90fa61229261140a
# 3  In stock (20 available)  6957f44c3847a760
# 4  In stock (20 available)  e00eb4fd7b871a48
# 5  In stock (20 available)  4165285e1663650f
#
#                                          Descripcion
# 1  \n    It's hard to imagine a world without A L...
# 2  \n    "Erotic and absorbing...Written with sta...
# 3  \n    Dans une France assez proche de la nÃ´tr...
# 4  \n    WICKED above her hipbone, GIRL across he...
# 5  \n    From a renowned historian comes a ground...

# %%
#Saber el tamño del dataset
df.shape
# Out:
# (1049, 6)

# %%
#La columna precio tiene simbolos que impiden trabajar este dato como un entero, entonces se elimina
df['Precio'] = df['Precio'].replace('[\£Â,]', '', regex=True)

# %%
df.head()
# Out:
#                                   Título Precio Rating  \
# 1                   A Light in the Attic  51.77  Three
# 2                     Tipping the Velvet  53.74    One
# 3                             Soumission  50.10    One
# 4                          Sharp Objects  47.82   Four
# 5  Sapiens: A Brief History of Humankind  54.23   Five
#
#             Disponibilidad               UPC  \
# 1  In stock (22 available)  a897fe39b1053632
# 2  In stock (20 available)  90fa61229261140a
# 3  In stock (20 available)  6957f44c3847a760
# 4  In stock (20 available)  e00eb4fd7b871a48
# 5  In stock (20 available)  4165285e1663650f
#
#                                          Descripcion
# 1  \n    It's hard to imagine a world without A L...
# 2  \n    "Erotic and absorbing...Written with sta...
# 3  \n    Dans une France assez proche de la nÃ´tr...
# 4  \n    WICKED above her hipbone, GIRL across he...
# 5  \n    From a renowned historian comes a ground...

# %%
# Crear un diccionario para mapear las palabras a números
rating_dict = {'One': 1, 'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5}

# Aplicar el mapeo a la columna 'Rating'
df['Rating'] = df['Rating'].map(rating_dict)

# %%
df.head()
# Out:
#                                   Título Precio  Rating  \
# 1                   A Light in the Attic  51.77     3.0
# 2                     Tipping the Velvet  53.74     1.0
# 3                             Soumission  50.10     1.0
# 4                          Sharp Objects  47.82     4.0
# 5  Sapiens: A Brief History of Humankind  54.23     5.0
#
#             Disponibilidad               UPC  \
# 1  In stock (22 available)  a897fe39b1053632
# 2  In stock (20 available)  90fa61229261140a
# 3  In stock (20 available)  6957f44c3847a760
# 4  In stock (20 available)  e00eb4fd7b871a48
# 5  In stock (20 available)  4165285e1663650f
#
#                                          Descripcion
# 1  \n    It's hard to imagine a world without A L...
# 2  \n    "Erotic and absorbing...Written with sta...
# 3  \n    Dans une France assez proche de la nÃ´tr...
# 4  \n    WICKED above her hipbone, GIRL across he...
# 5  \n    From a renowned historian comes a ground...

# %%
#De la columna disponibilidad solo es necesario el numero
df['Disponibilidad'] = df['Disponibilidad'].str.extract('(\d+)')
df.head()
# Out:
#                                   Título Precio  Rating Disponibilidad  \
# 1                   A Light in the Attic  51.77     3.0             22
# 2                     Tipping the Velvet  53.74     1.0             20
# 3                             Soumission  50.10     1.0             20
# 4                          Sharp Objects  47.82     4.0             20
# 5  Sapiens: A Brief History of Humankind  54.23     5.0             20
#
#                 UPC                                        Descripcion
# 1  a897fe39b1053632  \n    It's hard to imagine a world without A L...
# 2  90fa61229261140a  \n    "Erotic and absorbing...Written with sta...
# 3  6957f44c3847a760  \n    Dans une France assez proche de la nÃ´tr...
# 4  e00eb4fd7b871a48  \n    WICKED above her hipbone, GIRL across he...
# 5  4165285e1663650f  \n    From a renowned historian comes a ground...

# %%
# Crear una máscara booleana para las filas que contienen el nombre de las columnas
mask = df.isin(df.columns)

# Usar la máscara para filtrar las filas que no contienen el nombre de las columnas
df = df[~mask.any(axis=1)]

# %%
df.head(20)
# Out:
#                                                Título Precio  Rating  \
# 1                                A Light in the Attic  51.77     3.0
# 2                                  Tipping the Velvet  53.74     1.0
# 3                                          Soumission  50.10     1.0
# 4                                       Sharp Objects  47.82     4.0
# 5               Sapiens: A Brief History of Humankind  54.23     5.0
# 6                                     The Requiem Red  22.65     1.0
# 7   The Dirty Little Secrets of Getting Your Dream...  33.34     4.0
# 8   The Coming Woman: A Novel Based on the Life of...  17.93     3.0
# 9   The Boys in the Boat: Nine Americans and Their...  22.60     4.0
# 10                                    The Black Maria  52.15     1.0
# 11     Starving Hearts (Triangular Trade Trilogy, #1)  13.99     2.0
# 12                              Shakespeare's Sonnets  20.66     4.0
# 13                                        Set Me Free  17.46     5.0
# 14  Scott Pilgrim's Precious Little Life (Scott Pi...  52.29     5.0
# 15                          Rip it Up and Start Again  35.02     5.0
# 16  Our Band Could Be Your Life: Scenes from the A...  57.25     3.0
# 17                                               Olio  23.88     1.0
# 18  Mesaerion: The Best Science Fiction Stories 18...  37.59     1.0
# 19                       Libertarianism for Beginners  51.33     2.0
# 20                            It's Only the Himalayas  45.17     2.0
#
#    Disponibilidad               UPC  \
# 1              22  a897fe39b1053632
# 2              20  90fa61229261140a
# 3              20  6957f44c3847a760
# 4              20  e00eb4fd7b871a48
# 5              20  4165285e1663650f
# 6              19  f77dbf2323deb740
# 7              19  2597b5a345f45e1b
# 8              19  e72a5dfc7e9267b2
# 9              19  e10e1e165dc8be4a
# 10             19  1dfe412b8ac00530
# 11             19  0312262ecafa5a40
# 12             19  30a7f60cd76ca58c
# 13             19  ce6396b0f23f6ecc
# 14             19  3b1c02bac2a429e6
# 15             19  a34ba96d4081e6a4
# 16             19  deda3e61b9514b83
# 17             19  feb7cc7701ecf901
# 18             19  e30f54cea9b38190
# 19             19  a18a4f574854aced
# 20             19  a22124811bfa8350
#
#                                           Descripcion
# 1   \n    It's hard to imagine a world without A L...
# 2   \n    "Erotic and absorbing...Written with sta...
# 3   \n    Dans une France assez proche de la nÃ´tr...
# 4   \n    WICKED above her hipbone, GIRL across he...
# 5   \n    From a renowned historian comes a ground...
# 6   \n    Patient Twenty-nine.A monster roams the ...
# 7   \n    Drawing on his extensive experience eval...
# 8   \n    "If you have a heart, if you have a soul...
# 9   \n    For readers of Laura Hillenbrand's Seabi...
# 10  \n    Praise for Aracelis Girmay:"[Girmay's] e...
# 11  \n    Since her assault, Miss Annette Chetwynd...
# 12  \n    This book is an important and complete c...
# 13  \n    Aaron Ledbetterâs future had been plan...
# 14  \n    Scott Pilgrim's life is totally sweet. H...
# 15  \n    Punk's raw power rejuvenated rock, but b...
# 16  \n    This is the never-before-told story of t...
# 17  \n    Part fact, part fiction, Tyehimba Jess's...
# 18  \n    Andrew Barger, award-winning author and ...
# 19  \n    Libertarianism isn't about winning elect...
# 20  \n    âWherever you go, whatever you do, jus...

# %%
df.set_index('UPC', inplace=True)

# %%
#Guardamos todos los cambios en un nuevo archivo plano
df.to_csv("cleanData.csv", index=False)

# %% [markdown]
# #Codigo de scraping
# ```
# import requests
# from bs4 import BeautifulSoup
# import csv
# import os
#
# def scrap(url1):
#     x=0
#     # URL de la página web
#     url = "https://books.toscrape.com/catalogue/"
#
#     # Realizar una solicitud GET a la página web
#
#     response = requests.get(url1)
#
#
#     # Comprobar si la solicitud fue exitosa
#     if response.status_code == 200:
#         # Crear un objeto BeautifulSoup
#         soup = BeautifulSoup(response.text, "html.parser")
#
#         # Encontrar todos los elementos de libro
#         books = soup.find_all("article", class_="product_pod")
#
#         # Crear un archivo CSV para escribir los datos
#         with open("sample.csv", "a", newline="", encoding="utf-8") as csvfile:
#             fieldnames = ["Título", "Precio", "Rating", "Disponibilidad", "UPC", "Descripcion"]
#             writer = csv.DictWriter(csvfile, fieldnames=fieldnames, delimiter='|')
#
#             # Comprobar si el archivo está vacío antes de escribir la cabecera
#             if os.stat("sample.csv").st_size == 0:
#                 writer.writeheader()
#
#             writer.writeheader()
#
#             for book in books:
#                 # Extraer el título del libro
#                 title = book.find("h3").find("a")["title"]
#
#                 # Buscar el precio del libro
#                 price_element = book.find("p", class_="price_color")
#                 price = price_element.text if price_element else "Precio no disponible"
#
#                 # Extraer el rating del libro
#                 rating_element = book.find("p", class_="star-rating")
#                 rating = rating_element["class"][1] if rating_element else "Rating no disponible"
#
#                 # Acceder a la URL del libro para obtener la descripción del producto
#                 book_url = url + book.find("h3").find("a")["href"]
#                 book_response = requests.get(book_url)
#
#                 #book_soup = None
#                 if book_response.status_code == 200:
#                     x=x+1
#                     print(x)
#                     book_soup = BeautifulSoup(book_response.text, "html.parser")
#                     product_description = book_soup.find("meta", {"name": "description"})["content"]
#
#                 else:
#                     product_description = "F"
#                 # Buscar la disponibilidad del libro
#                 availability_element = book_soup.find("th", string="Availability")
#                 availability = availability_element.find_next("td").get_text() if availability_element else "Disponibilidad no disponible"
#
#                 upc_element = book_soup.find("th", string="UPC")
#                 upc = upc_element.find_next_sibling("td").text if upc_element else "UPC no disponible"
#                 # Escribir los detalles del libro en el archivo CSV
#                 writer.writerow({
#                     "Título": title,
#                     "Precio": price,
#                     "Rating": rating,
#                     "Disponibilidad": availability,
#                     "UPC":upc,
#                     "Descripcion": product_description
#                 })
#
#         print("Los datos se han guardado en libros.csv")
#     else:
#         print("Error al acceder a la página web")
#
#
#
# for i in range(1, 51):
#     url = f'https://books.toscrape.com/catalogue/page-{i}.html'
#     print("Scraping: "+url)
#     scrap(url)
#
#
# ```
